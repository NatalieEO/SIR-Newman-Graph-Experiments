# %%
import pandas as pd
import plotly
import matplotlib.pyplot as mp
import plotly.plotly as py 
import plotly.graph_objs as go
import numpy as np
from plotly.graph_objs import *
import plotly.figure_factory as FF

# %%
triFree1Mil_20 = pd.read_csv('../1milData/triFree20.csv', sep=',')

# %%
triFree1Mil_20['PortionInf'] = triFree1Mil_20['NumInfected']/triFree1Mil_20['NumNodes']
triFree1Mil_20['InfRate'] =triFree1Mil_20['InfRate']/10000
triFree1Mil_20.tail()
# Out:
#        NumNodes  GroupSize  AvgDeg  InfRate  NumInfected  PortionInf
# 40095   1000000         30      20      0.4       999938    0.999938
# 40096   1000000         30      20      0.4       999921    0.999921
# 40097   1000000         30      20      0.4       999919    0.999919
# 40098   1000000         30      20      0.4       999917    0.999917
# 40099   1000000         30      20      0.4       999929    0.999929

# %%
triFree1Mil_20.head()
# Out:
#    NumNodes  GroupSize  AvgDeg  InfRate  NumInfected  PortionInf
# 0   1000000         30      20      0.0            1    0.000001
# 1   1000000         30      20      0.0            1    0.000001
# 2   1000000         30      20      0.0            1    0.000001
# 3   1000000         30      20      0.0            1    0.000001
# 4   1000000         30      20      0.0            1    0.000001

# %%
triFree1Mil_20= triFree1Mil_20[['InfRate', 'PortionInf']]
triFree1Mil_20 = triFree1Mil_20.groupby('InfRate').mean()
triFree1Mil_20.head()
# Out:
#            PortionInf
# InfRate
# 0.000    1.000000e-06
# 0.001    1.030000e-06
# 0.002    1.020000e-06
# 0.003    1.040000e-06
# 0.004    1.040000e-06

# %%
triFree10000_20 = pd.read_csv('../data/triFree20redo.csv', sep=',')
triFree10000_20['PortionInf'] = triFree10000_20['NumInfected']/triFree10000_20['NumNodes']
triFree10000_20['InfRate'] =triFree10000_20['InfRate']/10000

# %%
triFree10000_20= triFree10000_20[['InfRate', 'PortionInf']]
triFree10000_20 = triFree10000_20.groupby('InfRate').mean()
triFree10000_20.head()
# Out:
#          PortionInf
# InfRate
# 0.000      0.000100
# 0.001      0.000102
# 0.002      0.000105
# 0.003      0.000101
# 0.004      0.000108

# %%
mp.figure(figsize=(25,12))
mp.title('Triangle Free, Degree=20', fontsize=22)

mp.plot(triFree1Mil_20[.05:.30], 'ko--', label='Triangle Free 1 Million')
//mp.plot(triFree10000_20[0.05:.30], 's--', label='Triangle Free 10 Thousand', color='#a8a8a8')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()
