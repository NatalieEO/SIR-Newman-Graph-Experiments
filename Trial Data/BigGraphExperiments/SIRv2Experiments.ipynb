# %%
import pandas as pd
import plotly
import matplotlib.pyplot as mp
import plotly.plotly as py 
import plotly.graph_objs as go
import numpy as np
from plotly.graph_objs import *

import plotly.figure_factory as FF

# %%
def createChart(csvFile):   
    chart = pd.read_csv(csvFile, sep=',')
    chart['PortionInf'] = chart['NumInfected']/chart['NumNodes']
    chart['InfRate'] = chart['InfRate']/10000
    chart = chart[['InfRate', 'NumInfected']]
    chart = chart.groupby('InfRate').mean()
    return chart;

# %% [markdown]
# <h1>1 Million Nodes, Average Degree 5, Group Size 8, 5 Seeds</h1>

# %%
noGroups5 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/NoGroups-SIR-1mil-GS0-AD5.csv")
triangle5 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/Triangle-SIR-1mil-GS8-AD5-4.csv")
triFree5 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/TriFree-SIR-1mil-GS8-AD5.csv")

# %%
mp.figure(figsize=(25,12))
mp.title('Size 1 million Nodes, Average Degree 5, Group Size 8', fontsize=22)

mp.plot(triFree5[:.5], 'ms--', label='Triangle Free')

mp.plot(triangle5[:.5], 'b*--', label='Triangles')

mp.plot(noGroups5[:.5], 'go--', label='no Groups')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
noGroups16 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/NoGroups-SIR-1mil-GS0-AD16.csv")
triangle16 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/Triangle-SIR-1mil-GS30-AD16-15.csv")
triFree16 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/TriFree-SIR-1mil-GS30-AD16.csv")

# %% [markdown]
# <h1>1 Million Nodes, Average Degree 16, Group Size 30, 5 Seeds</h1>

# %%
mp.figure(figsize=(25,12))
mp.title('Size 1 million Nodes, Average Degree 16, Group Size 30', fontsize=22)

mp.plot(triFree16[:.2], 'ms--', label='Triangle Free')

mp.plot(triangle16[:.2], 'b*--', label='Triangles')

mp.plot(noGroups16[:.2], 'go--', label='no Groups')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
noGroups20 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/NoGroups-SIR-1mil-GS0-AD20.csv")
triangle20 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/Triangle-SIR-1mil-GS30-AD20-15.csv")
triFree20 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/TriFree-SIR-1mil-GS30-AD20.csv")

# %% [markdown]
# <h1>1 Million Nodes, Average Degree 20, Group Size 30, 5 Seeds</h1>

# %%
mp.figure(figsize=(25,12))
mp.title('Size 1 million Nodes, Average Degree 20, Group Size 30', fontsize=22)

mp.plot(triFree20[:.15], 'ms--', label='Triangle Free')

mp.plot(triangle20[:.15], 'b*--', label='Triangles')

mp.plot(noGroups20[:.15], 'go--', label='no Groups')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
noGroups25 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/NoGroups-SIR-1mil-GS0-AD25.csv")
triangle25 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/Triangle-SIR-1mil-GS30-AD25-15.csv")
triFree25 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/TriFree-SIR-1mil-GS30-AD25.csv")

# %% [markdown]
# <h1>1 Million Nodes, Average Degree 25, Group Size 30, 5 Seeds</h1>

# %%
mp.figure(figsize=(25,12))
mp.title('Size 1 million Nodes, Average Degree 25, Group Size 30', fontsize=22)

mp.plot(triFree25[:.15], 'ms--', label='Triangle Free')

mp.plot(triangle25[:.15], 'b*--', label='Triangles')

mp.plot(noGroups25[:.15], 'go--', label='no Groups')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
noGroups30 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/NoGroups-SIR-1mil-GS0-AD30.csv")
triangle30 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/Triangle-SIR-1mil-GS30-AD30-15.csv")
triFree30 = createChart("../1milData/1mil5SeedsMultiDayData/Summer/TriFree-SIR-1mil-GS30-AD30.csv")

# %% [markdown]
# <h1>1 Million Nodes, Average Degree 30, Group Size 30, 5 Seeds</h1>

# %%
mp.figure(figsize=(25,12))
mp.title('Size 1 million Nodes, Average Degree 25, Group Size 30', fontsize=22)

mp.plot(triFree30[:.10], 'ms--', label='Triangle Free')

mp.plot(triangle30[:.10], 'b*--', label='Triangles')

mp.plot(noGroups30[:.10], 'go--', label='no Groups')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()
