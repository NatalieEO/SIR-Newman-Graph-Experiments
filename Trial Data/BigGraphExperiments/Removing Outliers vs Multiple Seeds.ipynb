# %% [raw]
# import pandas as pd
# import plotly
# import matplotlib.pyplot as mp
# import plotly.plotly as py
# import plotly.graph_objs as go
# import numpy as np
# from plotly.graph_objs import *
# import plotly.figure_factory as FF

# %%
oneCallTrial3 = pd.read_csv('../1milData/randComparison/triFree20-1call-trial3.csv', sep=',')
oneCallTrial3['PortionInf'] = oneCallTrial3['NumInfected']/oneCallTrial3['NumNodes']
oneCallTrial3['InfRate'] =oneCallTrial3['InfRate']/10000
oneCallTrial3.tail()
# Out:
#       NumNodes  GroupSize  AvgDeg  InfRate  NumInfected  PortionInf
# 1225   1000000         30      20      0.4       999934    0.999934
# 1226   1000000         30      20      0.4       999955    0.999955
# 1227   1000000         30      20      0.4       999944    0.999944
# 1228   1000000         30      20      0.4       999948    0.999948
# 1229   1000000         30      20      0.4       999951    0.999951

# %%
noDiseaseSpreadFilter = oneCallTrial3['NumInfected'] == 1
cutNoDiseaseSpreadFilter = oneCallTrial3['NumInfected'] > 1
DiseaseSpreadFilter = oneCallTrial3['NumInfected'] >= 10
countDiseaseSpreadFilter = oneCallTrial3['NumInfected'] < 10

# %%
noDiseaseSpread = oneCallTrial3[noDiseaseSpreadFilter]
noDiseaseSpread.tail()
# Out:
#      NumNodes  GroupSize  AvgDeg  InfRate  NumInfected  PortionInf
# 521   1000000         30      20     0.17            1    0.000001
# 535   1000000         30      20     0.17            1    0.000001
# 568   1000000         30      20     0.18            1    0.000001
# 577   1000000         30      20     0.19            1    0.000001
# 580   1000000         30      20     0.19            1    0.000001

# %%
noDiseaseSpread.head()
# Out:
#    NumNodes  GroupSize  AvgDeg  InfRate  NumInfected  PortionInf
# 0   1000000         30      20      0.0            1    0.000001
# 1   1000000         30      20      0.0            1    0.000001
# 2   1000000         30      20      0.0            1    0.000001
# 3   1000000         30      20      0.0            1    0.000001
# 4   1000000         30      20      0.0            1    0.000001

# %%
noDiseaseSpread = noDiseaseSpread[['InfRate', 'NumInfected']]

# %%
noDiseaseSpread = noDiseaseSpread.groupby('InfRate').count()

# %%
noDiseaseSpread[.05:.14]
# Out:
#          NumInfected
# InfRate
# 0.05              15
# 0.06               7
# 0.07              12
# 0.08               9
# 0.09               8
# 0.10               7
# 0.11               8
# 0.12               3
# 0.13               3
# 0.14               1

# %%
mp.figure(figsize=(25,12))
mp.title('Number of Times Disease did not Spread', fontsize=22)

mp.plot(noDiseaseSpread, 'ms', label='Triange Free Trial 3')
mp.xticks(np.arange(0, .2, .05))
legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
removedNoDiseaseSpread = oneCallTrial3[NoDiseaseSpreadFilter]
removedNoDiseaseSpread = removedNoDiseaseSpread[['InfRate', 'PortionInf']]
removedNoDiseaseSpread = removedNoDiseaseSpread.groupby('InfRate').mean()

# %%
mp.figure(figsize=(25,12))
mp.title('Average Disease Spread with NumInfected = 1 Eliminated', fontsize=22)

mp.plot(removedNoDiseaseSpread, 'ms--', label='Triange Free Trial 3')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
countMinDiseaseSpread = oneCallTrial3[countDiseaseSpreadFilter]
countMinDiseaseSpread = countMinDiseaseSpread[['InfRate', 'NumInfected']]
countMinDiseaseSpread = countMinDiseaseSpread.groupby('InfRate').count()
countMinDiseaseSpread.head()
# Out:
#          NumInfected
# InfRate
# 0.00              30
# 0.01              30
# 0.02              30
# 0.03              28
# 0.04              29

# %%
countMinDiseaseSpread[.09:.12]
# Out:
#          NumInfected
# InfRate
# 0.09              12
# 0.10               8
# 0.11               9
# 0.12               3

# %%
mp.figure(figsize=(25,12))
mp.title('Number of Times a Disease Spread to Less Than 10 peaople', fontsize=22)

mp.plot(countMinDiseaseSpread, 'ms', label='Triange Free Trial 3')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
mp.figure(figsize=(25,12))
mp.title('Number of Outliers', fontsize=22)

mp.plot(countMinDiseaseSpread, 'ms--', label='Spread less than 10 people')
mp.plot(noDiseaseSpread, 'bs--', label='No Spread')
mp.xticks(np.arange(0, .3, .05))

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
minimalDiseaseSpread = oneCallTrial3[DiseaseSpreadFilter]
minimalDiseaseSpread.tail()
# Out:
#       NumNodes  GroupSize  AvgDeg  InfRate  NumInfected  PortionInf
# 1225   1000000         30      20      0.4       999934    0.999934
# 1226   1000000         30      20      0.4       999955    0.999955
# 1227   1000000         30      20      0.4       999944    0.999944
# 1228   1000000         30      20      0.4       999948    0.999948
# 1229   1000000         30      20      0.4       999951    0.999951

# %%
minimalDiseaseSpread = minimalDiseaseSpread[['InfRate', 'PortionInf']]
minimalDiseaseSpread = minimalDiseaseSpread.groupby('InfRate').mean()

# %%
mp.figure(figsize=(25,12))
mp.title('Average Disease Spread with NumInfected <10 Eliminated', fontsize=22)

mp.plot(minimalDiseaseSpread, 'ms--', label='Triange Free Trial 3')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %% [markdown]
# <br>
# <br>
# <br>
# <br>

# %%
oneCall3Seeds = pd.read_csv('../1milData/randComparison/triFree20-1call-3seeds-trial1.csv', sep=',')

# %%
oneCall3Seeds['PortionInf'] = oneCall3Seeds['NumInfected']/oneCall3Seeds['NumNodes']
oneCall3Seeds['InfRate'] =oneCall3Seeds['InfRate']/10000
oneCall3Seeds.tail()
# Out:
#       NumNodes  GroupSize  AvgDeg  InfRate  NumInfected  PortionInf
# 1225   1000000         30      20      0.4       999949    0.999949
# 1226   1000000         30      20      0.4       999937    0.999937
# 1227   1000000         30      20      0.4       999955    0.999955
# 1228   1000000         30      20      0.4       999956    0.999956
# 1229   1000000         30      20      0.4       999961    0.999961

# %%
oneCall3Seeds= oneCall3Seeds[['InfRate', 'PortionInf']]
oneCall3Seeds = oneCall3Seeds.groupby('InfRate').mean()
oneCall3Seeds.head()
# Out:
#          PortionInf
# InfRate
# 0.00       0.000003
# 0.01       0.000003
# 0.02       0.000004
# 0.03       0.000006
# 0.04       0.000010

# %%
mp.figure(figsize=(25,12))
mp.title('Average Disease Spread', fontsize=22)

mp.plot(oneCall3Seeds[:.30], 'ms--', label='3 Seeds')
#mp.plot(minimalDiseaseSpread[:.3], 'bs--', label='1 Seed with < 10 eliminated ')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()
