# %%
import pandas as pd
import plotly
import matplotlib.pyplot as mp
import plotly.plotly as py 
import plotly.graph_objs as go
import numpy as np
from plotly.graph_objs import *
import plotly.figure_factory as FF

# %%
gnr10000_20 = pd.read_csv('../data/gnr20.csv', sep=',')
triFree10000_20 = pd.read_csv('../data/triFree20.csv', sep=',')
tri10000_20 = pd.read_csv('../data/triGraph20.csv', sep=',')

# %%
gnr10000_20.head()
# Out:
#    NumNodes  GroupSize  AvgDeg  InfRate  NumInfected
# 0     10000         30      20        0            5
# 1     10000         30      20        0            5
# 2     10000         30      20        0            5
# 3     10000         30      20        0            5
# 4     10000         30      20        0            5

# %%
gnr10000_20['PortionInf'] = gnr10000_20['NumInfected']/gnr10000_20['NumNodes']
gnr10000_20['InfRate'] =gnr10000_20['InfRate']/10000
triFree10000_20['PortionInf'] = triFree10000_20['NumInfected']/triFree10000_20['NumNodes']
triFree10000_20['InfRate'] =triFree10000_20['InfRate']/10000
tri10000_20['PortionInf'] = tri10000_20['NumInfected']/triFree10000_20['NumNodes']
tri10000_20['InfRate'] =tri10000_20['InfRate']/10000

# %%
gnr10000_20= gnr10000_20[['InfRate', 'PortionInf']]
gnr10000_20 = gnr10000_20.groupby('InfRate').mean()
gnr10000_20.head()
# Out:
#          PortionInf
# InfRate
# 0.000      0.000500
# 0.001      0.000511
# 0.002      0.000521
# 0.003      0.000535
# 0.004      0.000545

# %%
triFree10000_20= triFree10000_20[['InfRate', 'PortionInf']]
triFree10000_20 = triFree10000_20.groupby('InfRate').mean()
triFree10000_20.head()
# Out:
#          PortionInf
# InfRate
# 0.000      0.000500
# 0.001      0.000522
# 0.002      0.000527
# 0.003      0.000535
# 0.004      0.000537

# %%
tri10000_20= tri10000_20[['InfRate', 'PortionInf']]
tri10000_20 = tri10000_20.groupby('InfRate').mean()
tri10000_20.head()
# Out:
#          PortionInf
# InfRate
# 0.000      0.000500
# 0.001      0.000506
# 0.002      0.000518
# 0.003      0.000539
# 0.004      0.000545

# %% [markdown]
# <br>
# <br>
# <br>
# <h1>Avgerage Degree 20</h1>

# %% [markdown]
# <h2>GNP vs Triangle Free vs Triangle, 10000 Nodes</h2>

# %%
mp.figure(figsize=(25,12))
mp.title('GNP vs TriFree vs Triangle, avgDeg=20, nodes = 10000', fontsize=22)
mp.plot(gnr10000_20[0.03:], 's--', label='GNP', color ='#2e86c1')
mp.plot(triFree10000_20[0.03:], 'ko--', label='Triangle Free', color='#009d00')
mp.plot(tri10000_20[0.03:], 'm*--', label='Triangle', color='#ff4e4e')
legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %% [markdown]
# <br>
# <br>
# <br>
# <br>

# %%
gnr1000_20 = pd.read_csv('../1000data/gnr20.csv', sep=',')
triFree1000_20 = pd.read_csv('../1000data/triFree20.csv', sep=',')
tri1000_20 = pd.read_csv('../1000data/triGraph20.csv', sep=',')

# %%
gnr1000_20['PortionInf'] = gnr1000_20['NumInfected']/gnr1000_20['NumNodes']
gnr1000_20['InfRate'] =gnr1000_20['InfRate']/10000
triFree1000_20['PortionInf'] = triFree1000_20['NumInfected']/triFree1000_20['NumNodes']
triFree1000_20['InfRate'] =triFree1000_20['InfRate']/10000
tri1000_20['PortionInf'] = tri1000_20['NumInfected']/triFree1000_20['NumNodes']
tri1000_20['InfRate'] =tri1000_20['InfRate']/10000

# %%
gnr1000_20.tail()
# Out:
#        NumNodes  GroupSize  AvgDeg  InfRate  NumInfected  PortionInf
# 10095      1000         30      20      0.1          799       0.799
# 10096      1000         30      20      0.1          792       0.792
# 10097      1000         30      20      0.1          795       0.795
# 10098      1000         30      20      0.1          808       0.808
# 10099      1000         30      20      0.1          819       0.819

# %%
triFree1000_20= triFree1000_20[['InfRate', 'PortionInf']]
triFree1000_20 = triFree1000_20.groupby('InfRate').mean()
triFree1000_20.head()
# Out:
#          PortionInf
# InfRate
# 0.000       0.00500
# 0.001       0.00515
# 0.002       0.00524
# 0.003       0.00535
# 0.004       0.00535

# %%
tri1000_20= tri1000_20[['InfRate', 'PortionInf']]
tri1000_20 = tri1000_20.groupby('InfRate').mean()
tri1000_20.head()
# Out:
#          PortionInf
# InfRate
# 0.000       0.00500
# 0.001       0.00507
# 0.002       0.00519
# 0.003       0.00533
# 0.004       0.00542

# %%
gnr1000_20= gnr1000_20[['InfRate', 'PortionInf']]
gnr1000_20 = gnr1000_20.groupby('InfRate').mean()
gnr1000_20.head()
# Out:
#          PortionInf
# InfRate
# 0.000       0.00500
# 0.001       0.00513
# 0.002       0.00520
# 0.003       0.00538
# 0.004       0.00554

# %% [markdown]
# <h2>GNP vs Triangle Free vs Triangle Graph, 1000 Nodes</h2>

# %%
mp.figure(figsize=(25,12))
mp.title('GNP vs TriFree vs Triangle, avgDeg=20, nodes = 1000', fontsize=22)
mp.plot(gnr1000_20[0.03:], 'bs--', label='GNP')
mp.plot(triFree1000_20[0.03:], 'o--', label='Triangle Free', color='#004e00')
mp.plot(tri1000_20[0.03:], '*--', label='Triangle', color='#b10000')
legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %% [markdown]
# <h2>1000 vs 10000 Nodes</h2>
# <h4>For each type of graph</h4>

# %%
mp.figure(figsize=(25,15))
mp.title('GNP: 1000 vs 10000 Nodes, avgDeg=20', fontsize=22)
mp.plot(gnr1000_20[0.03:], 'bs--', label='GNP, 1000 Nodes')
mp.plot(gnr10000_20[0.03:], 's--', label='GNP, 10000 Nodes', color ='#2e86c1')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
mp.figure(figsize=(25,15))
mp.title('Triangle Free: 1000 vs 10000 Nodes, avgDeg=20', fontsize=22)

mp.plot(triFree1000_20[0.03:], 'o--', label='Triangle Free, 1000 Nodes', color='#004e00')
mp.plot(triFree10000_20[0.03:], 'o--', label='Triangle Free, 10000 Nodes', color='#009d00')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
mp.figure(figsize=(25,15))
mp.title('Triangle Free: 1000 vs 10000 Nodes, avgDeg=20', fontsize=22)

mp.plot(tri1000_20[0.03:], '*--', label='Triangle, 1000 Nodes', color='#b10000')
mp.plot(tri10000_20[0.03:], '*--', label='Triangle, 10000 Nodes', color='#ff4e4e')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %% [markdown]
# <h2>1000 vs 10000 Nodes Combined</h2>

# %%
mp.figure(figsize=(25,15))
mp.title('GNP vs Triangle-Free vs Triangle, avgDeg=20', fontsize=22)

mp.plot(gnr1000_20[0.03:], 'bs--', label='GNP, 1000 Nodes')
mp.plot(gnr10000_20[0.03:], 's--', label='GNP, 10000 Nodes', color ='#2e86c1')

mp.plot(triFree1000_20[0.03:], 'o--', label='Triangle Free, 1000 Nodes', color='#004e00')
mp.plot(triFree10000_20[0.03:], 'o--', label='Triangle Free, 10000 Nodes', color='#009d00')

mp.plot(tri1000_20[0.03:], '*--', label='Triangle, 1000 Nodes', color='#b10000')
mp.plot(tri10000_20[0.03:], '*--', label='Triangle, 10000 Nodes', color='#ff4e4e')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
# <h1>Average Degree 40</h1>

# %%
gnr10000_40 = pd.read_csv('../data/gnr40.csv', sep=',')
triFree10000_40 = pd.read_csv('../data/triFree40.csv', sep=',')
tri10000_40 = pd.read_csv('../data/triGraph40.csv', sep=',')

# %%
gnr10000_40['PortionInf'] = gnr10000_40['NumInfected']/gnr10000_40['NumNodes']
gnr10000_40['InfRate'] =gnr10000_40['InfRate']/10000
triFree10000_40['PortionInf'] = triFree10000_40['NumInfected']/triFree10000_40['NumNodes']
triFree10000_40['InfRate'] =triFree10000_40['InfRate']/10000
tri10000_40['PortionInf'] = tri10000_40['NumInfected']/triFree10000_40['NumNodes']
tri10000_40['InfRate'] =tri10000_40['InfRate']/10000

# %%
gnr10000_40= gnr10000_40[['InfRate', 'PortionInf']]
gnr10000_40 = gnr10000_40.groupby('InfRate').mean()
gnr10000_40.head()
# Out:
#          PortionInf
# InfRate
# 0.000      0.000500
# 0.001      0.000526
# 0.002      0.000563
# 0.003      0.000582
# 0.004      0.000607

# %%
triFree10000_40= triFree10000_40[['InfRate', 'PortionInf']]
triFree10000_40 = triFree10000_40.groupby('InfRate').mean()
triFree10000_40.head()
# Out:
#          PortionInf
# InfRate
# 0.000      0.000500
# 0.001      0.000518
# 0.002      0.000540
# 0.003      0.000569
# 0.004      0.000566

# %%
tri10000_40= tri10000_40[['InfRate', 'PortionInf']]
tri10000_40 = tri10000_40.groupby('InfRate').mean()
tri10000_40.head()
# Out:
#          PortionInf
# InfRate
# 0.000      0.000500
# 0.001      0.000523
# 0.002      0.000544
# 0.003      0.000567
# 0.004      0.000613

# %% [markdown]
# <h2>GNP vs TriFree vs Triangle, avgDeg=40, nodes = 10000</h2>

# %%
mp.figure(figsize=(25,12))
mp.title('GNP vs TriFree vs Triangle, avgDeg=40, nodes = 10000', fontsize=22)

mp.plot(gnr10000_40[0.015:.07], 's--', label='GNP', color ='#2e86c1')
mp.plot(triFree10000_40[0.015:.07], 'ko--', label='Triangle Free', color='#009d00')
mp.plot(tri10000_40[0.015:.07], 'm*--', label='Triangle', color='#ff4e4e')

#mp.plot(gnr10000_20[0.03:], 's--', label='GNP', color ='#2e86c1')
#mp.plot(triFree10000_20[0.03:], 'ko--', label='Triangle Free', color='#009d00')
#mp.plot(tri10000_20[0.03:], 'm*--', label='Triangle', color='#ff4e4e')
legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %% [markdown]
# <br>
# <br>
# <br>

# %%
gnr1000_40 = pd.read_csv('../1000data/gnr40.csv', sep=',')
triFree1000_40 = pd.read_csv('../1000data/triFree40.csv', sep=',')
tri1000_40 = pd.read_csv('../1000data/triGraph40.csv', sep=',')

# %%
gnr1000_40['PortionInf'] = gnr1000_40['NumInfected']/gnr1000_40['NumNodes']
gnr1000_40['InfRate'] =gnr1000_40['InfRate']/10000

triFree1000_40['PortionInf'] = triFree1000_40['NumInfected']/triFree1000_40['NumNodes']
triFree1000_40['InfRate'] =triFree1000_40['InfRate']/10000

tri1000_40['PortionInf'] = tri1000_40['NumInfected']/triFree1000_40['NumNodes']
tri1000_40['InfRate'] =tri1000_40['InfRate']/10000

# %%
gnr1000_40= gnr1000_40[['InfRate', 'PortionInf']]
gnr1000_40 = gnr1000_40.groupby('InfRate').mean()

# %%
triFree1000_40= triFree1000_40[['InfRate', 'PortionInf']]
triFree1000_40 = triFree1000_40.groupby('InfRate').mean()

tri1000_40= tri1000_40[['InfRate', 'PortionInf']]
tri1000_40 = tri1000_40.groupby('InfRate').mean()

# %% [markdown]
# <h2>GNP vs TriFree vs Triangle, avgDeg=40, nodes = 1000</h2>

# %%
mp.figure(figsize=(25,12))
mp.title('GNP vs TriFree vs Triangle Graphs', fontsize=22)
mp.plot(gnr1000_40[0.015:.07], 'bs--', label='GNP 1000 Nodes')


mp.plot(triFree1000_40[0.015:.07], 'o--', label='Triangle Free 1000 Nodes', color='#004e00')

mp.plot(tri1000_40[0.015:.07], '*--', label='Triangle 1000 Nodes', color='#b10000')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(2.0)
mp.show()

# %% [markdown]
# <h2>GNP vs Triangle Free vs Triangle Graphs</h2>

# %%
mp.figure(figsize=(25,12))
mp.title('GNP vs TriFree vs Triangle Graphs', fontsize=22)
mp.plot(gnr1000_40[0.015:.07], 'bs--', label='GNP 1000 Nodes')
mp.plot(gnr10000_40[0.015:.07], 's--', label='GNP 10000 Nodes', color ='#2e86c1')

mp.plot(triFree1000_40[0.015:.07], 'o--', label='Triangle Free 1000 Nodes', color='#004e00')
mp.plot(triFree10000_40[0.015:.07], 'o--', label='Triangle Free 10000 Nodes', color='#009d00')

mp.plot(tri1000_40[0.015:.07], '*--', label='Triangle 1000 Nodes', color='#b10000')
mp.plot(tri10000_40[0.015:.07], '*--', label='Triangle Nodes 10000 Nodes', color='#ff4e4e')
legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(2.0)
mp.show()

# %% [markdown]
# <br>
# <br>
# <br><br>
# <h2>Average Degree: 20 vs 40</h2>

# %%
mp.figure(figsize=(25,15))
mp.title('GNP Graph Comparison', fontsize=22)

mp.plot(gnr1000_20[0.03:], 'b^--', label='1000 Nodes, deg=20')
mp.plot(gnr10000_20[0.03:], '^--', label='10000 Nodes, deg=20', color ='#2e86c1')

mp.plot(gnr1000_40[0.015:], 'bs--', label='1000 Nodes, deg=40')
mp.plot(gnr10000_40[0.015:], 's--', label='10000 Nodes, deg=40', color ='#2e86c1')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(2.0)
mp.show()
mp.show();

# %%
mp.figure(figsize=(25,15))
mp.title('Triangle Graph Comparison', fontsize=22)

mp.plot(tri1000_20[0.03:], '^--', label='1000 Nodes, deg=20', color='#b10000')
mp.plot(tri10000_20[0.03:], '^--', label='10000 Nodes, deg=20', color='#ff4e4e')

mp.plot(tri1000_40[0.015:], '*--', label='1000 Nodes, deg=40', color='#b10000')
mp.plot(tri10000_40[0.015:], '*--', label='10000 Nodes, deg=40', color='#ff4e4e')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(2.0)
mp.show()

# %%
mp.figure(figsize=(25,15))
mp.title('Triangle Free Graph Comparison', fontsize=22)

mp.plot(triFree1000_20[0.03:], '^--', label='1000 Nodes, deg=20', color='#004e00')
mp.plot(triFree10000_20[0.03:], '^--', label='10000 Nodes, deg=20', color='#009d00')

mp.plot(triFree1000_40[0.015:], 'o--', label='1000 Nodes, deg=40', color='#004e00')
mp.plot(triFree10000_40[0.015:], 'o--', label='10000 Nodes, deg=40', color='#009d00')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(2.0)
mp.show()
