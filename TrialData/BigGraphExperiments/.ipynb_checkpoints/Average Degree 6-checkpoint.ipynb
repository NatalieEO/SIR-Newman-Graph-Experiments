# %%
import pandas as pd
import plotly
import matplotlib.pyplot as mp
import plotly.plotly as py 
import plotly.graph_objs as go
import numpy as np
from plotly.graph_objs import *

import plotly.figure_factory as FF

# %%
triFree = pd.read_csv('../1milData/1mil3seedsData/triFree6-1srandcall-3randseeds-trial2.csv', sep=',')
triFree2 = pd.read_csv('../1milData/1mil3seedsData/triFree6-1srandcall-3randseeds-trial1.csv', sep=',')
triFree3 = pd.read_csv('../1milData/1mil3seedsData/triFree6-1srandcall-3randseeds-trial3.csv', sep=',')

triangles = pd.read_csv('../1milData/1mil3seedsData/triGraph6-1srandcall-3randseeds-trial2.csv', sep=',')
triangles2 = pd.read_csv('../1milData/1mil3seedsData/triGraph6-1srandcall-3randseeds-trial1.csv', sep=',')
triangles3 = pd.read_csv('../1milData/1mil3seedsData/triGraph6-1srandcall-3randseeds-trial3.csv', sep=',')
triangles18 = pd.read_csv('../1milData/1mil3seedsData/triGraph18-15in-3randseeds-trial1.csv', sep=',')

noGroups = pd.read_csv('../1milData/1mil3seedsData/noGroups6-1srandcall-3randseeds-trial2.csv', sep=',')
noGroups2 = pd.read_csv('../1milData/1mil3seedsData/noGroups6-1srandcall-3randseeds-trial1.csv', sep=',')
noGroups3 = pd.read_csv('../1milData/1mil3seedsData/noGroups6-1srandcall-3randseeds-trial3.csv', sep=',')

# %%
triFree['PortionInf'] = triFree['NumInfected']/triFree['NumNodes']
triFree['InfRate'] = triFree['InfRate']/10000
triFree2['PortionInf'] = triFree2['NumInfected']/triFree2['NumNodes']
triFree2['InfRate'] = triFree2['InfRate']/10000
triFree3['PortionInf'] = triFree3['NumInfected']/triFree3['NumNodes']
triFree3['InfRate'] = triFree3['InfRate']/10000

triangles['PortionInf'] = triangles['NumInfected']/triangles['NumNodes']
triangles['InfRate'] = triangles['InfRate']/10000
triangles2['PortionInf'] = triangles2['NumInfected']/triangles2['NumNodes']
triangles2['InfRate'] = triangles2['InfRate']/10000
triangles3['PortionInf'] = triangles3['NumInfected']/triangles3['NumNodes']
triangles3['InfRate'] = triangles3['InfRate']/10000
triangles18['PortionInf'] = triangles18['NumInfected']/triangles18['NumNodes']
triangles18['InfRate'] = triangles18['InfRate']/10000

noGroups['PortionInf'] = noGroups['NumInfected']/noGroups['NumNodes']
noGroups['InfRate'] = noGroups['InfRate']/10000
noGroups2['PortionInf'] = noGroups2['NumInfected']/noGroups2['NumNodes']
noGroups2['InfRate'] = noGroups2['InfRate']/10000
noGroups3['PortionInf'] = noGroups3['NumInfected']/noGroups3['NumNodes']
noGroups3['InfRate'] = noGroups3['InfRate']/10000

# %%
triFree = triFree[['InfRate', 'NumInfected']]
triangles = triangles[['InfRate', 'NumInfected']]
noGroups = noGroups[['InfRate', 'NumInfected']]

triFree2 = triFree2[['InfRate', 'NumInfected']]
triangles2 = triangles2[['InfRate', 'NumInfected']]
noGroups2 = noGroups2[['InfRate', 'NumInfected']]

triFree3 = triFree3[['InfRate', 'NumInfected']]
triangles3 = triangles3[['InfRate', 'NumInfected']]
noGroups3 = noGroups3[['InfRate', 'NumInfected']]

triangles18 = triangles18[['InfRate', 'NumInfected']]

# %%
triFree = triFree.groupby('InfRate').mean()
triangles = triangles.groupby('InfRate').mean()
noGroups= noGroups.groupby('InfRate').mean()

triFree2 = triFree2.groupby('InfRate').mean()
triangles2 = triangles2.groupby('InfRate').mean()
noGroups2= noGroups2.groupby('InfRate').mean()

triFree3 = triFree3.groupby('InfRate').mean()
triangles3 = triangles3.groupby('InfRate').mean()
noGroups3= noGroups3.groupby('InfRate').mean()

triangles18 = triangles18.groupby('InfRate').mean()

# %%
mp.figure(figsize=(25,12))
mp.title('Group Size 10, Average Degree 6', fontsize=22)

mp.plot(triFree, 'ms--', label='Triangle Free')
#mp.plot(triFree2, 's--', label='Triangle Free 2', color='#F781F3')
#mp.plot(triFree3, 's--', label='Triangle Free 3', color='#F781F3')

mp.plot(triangles, 'b*--', label='Triangles')
#mp.plot(triangles2, 'b*--', label='Triangles 2', color='#58ACFA')
#mp.plot(triangles3, 'b*--', label='Triangles 3', color='#58ACFA')

mp.plot(noGroups, 'go--', label='no Groups')
#mp.plot(noGroups2, 'go--', label='no Groups 2', color = '#81F781')
#mp.plot(noGroups3, 'go--', label='no Groups 3', color = '#81F781')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
mp.figure(figsize=(25,12))
mp.title('Group Size 10, Average Degree 6', fontsize=22)

#mp.plot(triFree, 'ms--', label='Triangle Free')
mp.plot(triFree2, 's--', label='Triangle Free 2', color='#F781F3')
#mp.plot(triangles, 'b*--', label='Triangles')
mp.plot(triangles2, 'b*--', label='Triangles 2', color='#58ACFA')
#mp.plot(noGroups, 'go--', label='no Groups')
mp.plot(noGroups2, 'go--', label='no Groups 2', color = '#81F781')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
####50 TRIALS####
mp.figure(figsize=(25,12))
mp.title('Group Size 10, Average Degree 6', fontsize=22)

#mp.plot(triFree, 'ms--', label='Triangle Free')
#mp.plot(triFree2, 's--', label='Triangle Free 2', color='#F781F3')
mp.plot(triFree3, 's--', label='Triangle Free 3', color='#F6CEF5')

#mp.plot(triangles, 'b*--', label='Triangles')
#mp.plot(triangles2, 'b*--', label='Triangles 2', color='#58ACFA')
mp.plot(triangles3, 'b*--', label='Triangles 3', color='#CEECF5')

#mp.plot(noGroups, 'go--', label='no Groups')
#mp.plot(noGroups2, 'go--', label='no Groups 2', color = '#81F781')
mp.plot(noGroups3, 'go--', label='no Groups 3', color = '#81F781')
legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
mp.figure(figsize=(25,12))
mp.title('Group Size 10, Average Degree 6', fontsize=22)

mp.plot(triFree, 'ms--', label='Triangle Free')
mp.plot(triFree2, 's--', label='Triangle Free 2', color='#F781F3')
mp.plot(triFree3, 's--', label='Triangle Free 3', color='#F6CEF5')

mp.plot(triangles, 'b*--', label='Triangles')
mp.plot(triangles2, 'b*--', label='Triangles 2', color='#58ACFA')
mp.plot(triangles3, 'b*--', label='Triangles 3', color='#CEECF5')

mp.plot(noGroups, 'go--', label='no Groups')
mp.plot(noGroups2, 'go--', label='no Groups 2', color = '#81F781')
mp.plot(noGroups3, 'go--', label='no Groups 3', color = '#81F781')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
mp.figure(figsize=(25,12))
mp.title('Group Size 10, Average Degree 6', fontsize=22)

mp.plot(triFree, 'ms--', label='Triangle Free')
#mp.plot(triFree2, 's--', label='Triangle Free 2', color='#F781F3')
#mp.plot(triFree3, 's--', label='Triangle Free 3', color='#F781F3')

mp.plot(triangles, 'b*--', label='Triangles Degree 6')
#mp.plot(triangles2, 'b*--', label='Triangles 2', color='#58ACFA')
#mp.plot(triangles3, 'b*--', label='Triangles 3', color='#58ACFA')
mp.plot(triangles18, 'b*--', label= 'Triangles Degree 18', color='#58ACFA')

mp.plot(noGroups, 'go--', label='no Groups')
#mp.plot(noGroups2, 'go--', label='no Groups 2', color = '#81F781')
#mp.plot(noGroups3, 'go--', label='no Groups 3', color = '#81F781')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
triFreeClean = pd.read_csv('../1milData/1mil3seedsData/triFree6-1srandcall-3randseeds-trial2.csv', sep=',')
triFreeClean2 = pd.read_csv('../1milData/1mil3seedsData/triFree6-1srandcall-3randseeds-trial1.csv', sep=',')

trianglesClean = pd.read_csv('../1milData/1mil3seedsData/triGraph6-1srandcall-3randseeds-trial2.csv', sep=',')
trianglesClean2 = pd.read_csv('../1milData/1mil3seedsData/triGraph6-1srandcall-3randseeds-trial1.csv', sep=',')

noGroupsClean = pd.read_csv('../1milData/1mil3seedsData/noGroups6-1srandcall-3randseeds-trial2.csv', sep=',')
noGroupsClean2 = pd.read_csv('../1milData/1mil3seedsData/noGroups6-1srandcall-3randseeds-trial1.csv', sep=',')

# %%
triFreeClean['PortionInf'] = triFreeClean['NumInfected']/triFreeClean['NumNodes']
triFreeClean['InfRate'] = triFreeClean['InfRate']/10000
triFreeClean2['PortionInf'] = triFreeClean2['NumInfected']/triFreeClean2['NumNodes']
triFreeClean2['InfRate'] = triFreeClean2['InfRate']/10000

trianglesClean['PortionInf'] = trianglesClean['NumInfected']/trianglesClean['NumNodes']
trianglesClean['InfRate'] = trianglesClean['InfRate']/10000
trianglesClean2['PortionInf'] = trianglesClean2['NumInfected']/trianglesClean2['NumNodes']
trianglesClean2['InfRate'] = trianglesClean2['InfRate']/10000

noGroupsClean['PortionInf'] = noGroupsClean['NumInfected']/noGroupsClean['NumNodes']
noGroupsClean['InfRate'] = noGroupsClean['InfRate']/10000
noGroupsClean2['PortionInf'] = noGroupsClean2['NumInfected']/noGroupsClean2['NumNodes']
noGroupsClean2['InfRate'] = noGroupsClean2['InfRate']/10000

# %%
triFreeClean.head()
# Out:
#    NumNodes  GroupSize  AvgDeg  NumSeed  InfRate  NumInfected  PortionInf
# 0   1000000         10       6        3      0.0            3    0.000003
# 1   1000000         10       6        3      0.0            3    0.000003
# 2   1000000         10       6        3      0.0            3    0.000003
# 3   1000000         10       6        3      0.0            3    0.000003
# 4   1000000         10       6        3      0.0            3    0.000003

# %%
triFree_cutNoDiseaseSpreadFilter = triFreeClean['NumInfected'] >= 10
triangles_cutNoDiseaseSpreadFilter = trianglesClean['NumInfected'] >= 10
noGroups_cutNoDiseaseSpreadFilter = noGroupsClean['NumInfected'] >= 10

# %%
triFree_cutNoDiseaseSpread = triFreeClean[triFree_cutNoDiseaseSpreadFilter]
triangles_cutNoDiseaseSpread = trianglesClean[triangles_cutNoDiseaseSpreadFilter]
noGroups_cutNoDiseaseSpread = noGroupsClean[noGroups_cutNoDiseaseSpreadFilter]

# %%
triFreee_cutNoDiseaseSpreadFilter.head()
# Out:
#    NumNodes  GroupSize  AvgDeg  NumSeed  InfRate  NumInfected  PortionInf
# 0   1000000         10       6        3      0.0            3    0.000003
# 1   1000000         10       6        3      0.0            3    0.000003
# 2   1000000         10       6        3      0.0            3    0.000003
# 3   1000000         10       6        3      0.0            3    0.000003
# 4   1000000         10       6        3      0.0            3    0.000003

# %%
triFree_cutNoDiseaseSpread = triFree_cutNoDiseaseSpread[['InfRate', 'NumInfected']]
triangles_cutNoDiseaseSpread = triangles_cutNoDiseaseSpread[['InfRate', 'NumInfected']]
noGroups_cutNoDiseaseSpread = noGroups_cutNoDiseaseSpread[['InfRate', 'NumInfected']]

# %%
triFree_cutNoDiseaseSpread.head(10)
# Out:
#          NumInfected
# InfRate
# 0.07       10.500000
# 0.09       12.000000
# 0.10       12.000000
# 0.11       12.750000
# 0.12       11.000000
# 0.13       13.250000
# 0.14       14.500000
# 0.15       17.555556
# 0.16       14.250000
# 0.17       19.666667

# %%
triFree_cutNoDiseaseSpread = triFree_cutNoDiseaseSpread.groupby('InfRate').mean()
triangles_cutNoDiseaseSpread = triangles_cutNoDiseaseSpread.groupby('InfRate').mean()
noGroups_cutNoDiseaseSpread = noGroups_cutNoDiseaseSpread.groupby('InfRate').mean()

# %%
mp.figure(figsize=(25,12))
mp.title('Average Disease Spread with NumInfected < 10 Eliminated', fontsize=22)

mp.plot(triFree_cutNoDiseaseSpread, 'ms--', label='Triangle Free')
mp.plot(triangles_cutNoDiseaseSpread, 'b*--', label='Triangles')
mp.plot(noGroups_cutNoDiseaseSpread, 'go--', label='No Groups')

legend = mp.legend(loc='upper center', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()
