# %%
import pandas as pd
import plotly
import matplotlib.pyplot as mp
import plotly.plotly as py 
import plotly.graph_objs as go
import numpy as np
from plotly.graph_objs import *
import plotly.figure_factory as FF

# %%
once = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',')
loop = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',')
loopij = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',')

# %%
once.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']
once[239:248]
# Out:
#      NumNodes  GroupSize  AvgDeg  InfRate  NumInfected
# 239   1000000         30      20      800            5
# 240   1000000         30      20      800       537051
# 241   1000000         30      20      800       538914
# 242   1000000         30      20      800       535184
# 243   1000000         30      20      800            1
# 244   1000000         30      20      800       537984
# 245   1000000         30      20      800           26
# 246   1000000         30      20      800            1
# 247   1000000         30      20      800            2

# %%
once1 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=0)
once1.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

# %%
once2 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=1)
once2.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

once3 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=2)
once3.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

once4 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=3)
once4.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

once5 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=4)
once5.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

once6 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=5)
once6.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

once7 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=6)
once7.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

once8 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=7)
once8.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

once9 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=8)
once9.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

once10 = pd.read_csv('../1milData/randTesting/triFree20-1call.csv', sep=',' , skiprows=lambda x: x%30 !=9)
once10.columns =['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

# %%
once1['PortionInf'] = once1['NumInfected']/once1['NumNodes']
once1['InfRate'] =once1['InfRate']/10000
once1= once1[['InfRate', 'PortionInf']]

once2['PortionInf'] = once2['NumInfected']/once2['NumNodes']
once2['InfRate'] =once2['InfRate']/10000
once2= once2[['InfRate', 'PortionInf']]

once3['PortionInf'] = once3['NumInfected']/once3['NumNodes']
once3['InfRate'] =once3['InfRate']/10000
once3= once3[['InfRate', 'PortionInf']]

once4['PortionInf'] = once4['NumInfected']/once4['NumNodes']
once4['InfRate'] =once4['InfRate']/10000
once4= once4[['InfRate', 'PortionInf']]

once5['PortionInf'] = once5['NumInfected']/once5['NumNodes']
once5['InfRate'] =once5['InfRate']/10000
once5= once5[['InfRate', 'PortionInf']]

once6['PortionInf'] = once6['NumInfected']/once6['NumNodes']
once6['InfRate'] =once6['InfRate']/10000
once6= once6[['InfRate', 'PortionInf']]

once7['PortionInf'] = once7['NumInfected']/once7['NumNodes']
once7['InfRate'] =once7['InfRate']/10000
once7= once7[['InfRate', 'PortionInf']]

once8['PortionInf'] = once8['NumInfected']/once8['NumNodes']
once8['InfRate'] =once8['InfRate']/10000
once8= once8[['InfRate', 'PortionInf']]

once9['PortionInf'] = once9['NumInfected']/once9['NumNodes']
once9['InfRate'] =once9['InfRate']/10000
once9= once9[['InfRate', 'PortionInf']]

once10['PortionInf'] = once10['NumInfected']/once10['NumNodes']
once10['InfRate'] =once10['InfRate']/10000
once10= once10[['InfRate', 'PortionInf']]

# %%
once1 = once1.groupby('InfRate').mean()
once2 = once2.groupby('InfRate').mean()
once3 = once3.groupby('InfRate').mean()
once4 = once4.groupby('InfRate').mean()
once5 = once5.groupby('InfRate').mean()
once6 = once6.groupby('InfRate').mean()
once7 = once7.groupby('InfRate').mean()
once8 = once8.groupby('InfRate').mean()
once9 = once9.groupby('InfRate').mean()
once10 = once10.groupby('InfRate').mean()

# %%
mp.figure(figsize=(25,12))
mp.title('One Call to srand() with Time', fontsize=22)

mp.plot(once1, 's--', label='Trial 1', color='#a93226')
mp.plot(once2, 's--', label='Trial 2', color='#884ea0')
mp.plot(once3, 's--', label='Trial 3', color='#1f618d')
mp.plot(once4, 's--', label='Trial 4', color='#148f77')
mp.plot(once5, 's--', label='Trial 5', color='#f4d03f')
mp.plot(once6, 's--', label='Trial 6', color='#dc7633')
mp.plot(once7, 's--', label='Trial 7', color='#a6acaf')
mp.plot(once8, 's--', label='Trial 8', color='#73c6b6')
mp.plot(once9, 's--', label='Trial 9', color='#85c1e9')
mp.plot(once10, 's--', label='Trial 10', color='#17202a')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
loop1 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=1)
loop1.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop2 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=2)
loop2.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop3 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=3)
loop3.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop4 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=4)
loop4.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop5 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=5)
loop5.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop6 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=6)
loop6.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop7 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=7)
loop7.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop8 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=8)
loop8.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop9 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=9)
loop9.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loop10 = pd.read_csv('../1milData/randTesting/triFree20-loopTimeCalls.csv', sep=',', skiprows=lambda x: x%30 !=10)
loop10.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

# %%
loop1['PortionInf'] = loop1['NumInfected']/loop1['NumNodes']
loop1['InfRate'] =loop1['InfRate']/10000
loop1= loop1[['InfRate', 'PortionInf']]

loop2['PortionInf'] = loop2['NumInfected']/loop2['NumNodes']
loop2['InfRate'] =loop2['InfRate']/10000
loop2= loop2[['InfRate', 'PortionInf']]

loop3['PortionInf'] = loop3['NumInfected']/loop3['NumNodes']
loop3['InfRate'] =loop3['InfRate']/10000
loop3= loop3[['InfRate', 'PortionInf']]

loop4['PortionInf'] = loop4['NumInfected']/loop4['NumNodes']
loop4['InfRate'] =loop4['InfRate']/10000
loop4= loop4[['InfRate', 'PortionInf']]

loop5['PortionInf'] = loop5['NumInfected']/loop5['NumNodes']
loop5['InfRate'] =loop5['InfRate']/10000
loop5= loop5[['InfRate', 'PortionInf']]

loop6['PortionInf'] = loop6['NumInfected']/loop6['NumNodes']
loop6['InfRate'] =loop6['InfRate']/10000
loop6= loop6[['InfRate', 'PortionInf']]

loop7['PortionInf'] = loop7['NumInfected']/loop7['NumNodes']
loop7['InfRate'] =loop7['InfRate']/10000
loop7= loop7[['InfRate', 'PortionInf']]

loop8['PortionInf'] = loop8['NumInfected']/loop8['NumNodes']
loop8['InfRate'] =loop8['InfRate']/10000
loop8= loop8[['InfRate', 'PortionInf']]

loop9['PortionInf'] = loop9['NumInfected']/loop9['NumNodes']
loop9['InfRate'] =loop9['InfRate']/10000
loop9= loop9[['InfRate', 'PortionInf']]

loop10['PortionInf'] = loop10['NumInfected']/loop10['NumNodes']
loop10['InfRate'] =loop10['InfRate']/10000
loop10= loop10[['InfRate', 'PortionInf']]

# %%
loop1 = loop1.groupby('InfRate').mean()
loop2 = loop2.groupby('InfRate').mean()
loop3 = loop3.groupby('InfRate').mean()
loop4 = loop4.groupby('InfRate').mean()
loop5 = loop5.groupby('InfRate').mean()
loop6 = loop6.groupby('InfRate').mean()
loop7 = loop7.groupby('InfRate').mean()
loop8 = loop8.groupby('InfRate').mean()
loop9 = loop9.groupby('InfRate').mean()
loop10 = loop10.groupby('InfRate').mean()

# %%
mp.figure(figsize=(25,12))
mp.title('Loop Calls to srand with Time', fontsize=22)

mp.plot(loop1, 's--', label='Trial 1', color='#a93226')
mp.plot(loop2, 's--', label='Trial 2', color='#884ea0')
mp.plot(loop3, 's--', label='Trial 3', color='#1f618d')
mp.plot(loop4, 's--', label='Trial 4', color='#148f77')
mp.plot(loop5, 's--', label='Trial 5', color='#f4d03f')
mp.plot(loop6, 's--', label='Trial 6', color='#dc7633')
mp.plot(loop7, 's--', label='Trial 7', color='#a6acaf')
mp.plot(loop8, 's--', label='Trial 8', color='#73c6b6')
mp.plot(loop9, 's--', label='Trial 9', color='#85c1e9')
mp.plot(loop10, 's--', label='Trial 10', color='#17202a')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
loopij1 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=1)
loopij1.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij2 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=2)
loopij2.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij3 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=3)
loopij3.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij4 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=4)
loopij4.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij5 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=5)
loopij5.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij6 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=6)
loopij6.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij7 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=7)
loopij7.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij8 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=8)
loopij8.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij9 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=9)
loopij9.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

loopij10 = pd.read_csv('../1milData/randTesting/triFree20-loopijCalls.csv', sep=',', skiprows=lambda x: x%30 !=10)
loopij10.columns = ['NumNodes', 'GroupSize', 'AvgDeg', 'InfRate', 'NumInfected']

# %%
loopij1['PortionInf'] = loopij1['NumInfected']/loopij1['NumNodes']
loopij1['InfRate'] =loopij1['InfRate']/10000
loopij1= loopij1[['InfRate', 'PortionInf']]

loopij2['PortionInf'] = loopij2['NumInfected']/loopij2['NumNodes']
loopij2['InfRate'] =loopij2['InfRate']/10000
loopij2= loopij2[['InfRate', 'PortionInf']]

loopij3['PortionInf'] = loopij3['NumInfected']/loopij3['NumNodes']
loopij3['InfRate'] =loopij3['InfRate']/10000
loopij3= loopij3[['InfRate', 'PortionInf']]

loopij4['PortionInf'] = loopij4['NumInfected']/loopij4['NumNodes']
loopij4['InfRate'] =loopij4['InfRate']/10000
loopij4= loopij4[['InfRate', 'PortionInf']]

loopij5['PortionInf'] = loopij5['NumInfected']/loopij5['NumNodes']
loopij5['InfRate'] =loopij5['InfRate']/10000
loopij5= loopij5[['InfRate', 'PortionInf']]

loopij6['PortionInf'] = loopij6['NumInfected']/loopij6['NumNodes']
loopij6['InfRate'] =loopij6['InfRate']/10000
loopij6= loopij6[['InfRate', 'PortionInf']]

loopij7['PortionInf'] = loopij7['NumInfected']/loopij7['NumNodes']
loopij7['InfRate'] =loopij7['InfRate']/10000
loopij7= loopij7[['InfRate', 'PortionInf']]

loopij8['PortionInf'] = loopij8['NumInfected']/loopij8['NumNodes']
loopij8['InfRate'] =loopij8['InfRate']/10000
loopij8= loopij8[['InfRate', 'PortionInf']]

loopij9['PortionInf'] = loopij9['NumInfected']/loopij9['NumNodes']
loopij9['InfRate'] =loopij9['InfRate']/10000
loopij9= loopij9[['InfRate', 'PortionInf']]

loopij10['PortionInf'] = loopij10['NumInfected']/loopij10['NumNodes']
loopij10['InfRate'] =loopij10['InfRate']/10000
loopij10= loopij10[['InfRate', 'PortionInf']]

# %%
loopij1 = loopij1.groupby('InfRate').mean()
loopij2 = loopij2.groupby('InfRate').mean()
loopij3 = loopij3.groupby('InfRate').mean()
loopij4 = loopij4.groupby('InfRate').mean()
loopij5 = loopij5.groupby('InfRate').mean()
loopij6 = loopij6.groupby('InfRate').mean()
loopij7 = loopij7.groupby('InfRate').mean()
loopij8 = loopij8.groupby('InfRate').mean()
loopij9 = loopij9.groupby('InfRate').mean()
loopij10 = loopij10.groupby('InfRate').mean()

# %%
mp.figure(figsize=(25,12))
mp.title('Loop Calls to srand with i*j', fontsize=22)

mp.plot(loopij1, 's--', label='Trial 1', color='#a93226')
mp.plot(loopij2, 's--', label='Trial 2', color='#884ea0')
mp.plot(loopij3, 's--', label='Trial 3', color='#1f618d')
mp.plot(loopij4, 's--', label='Trial 4', color='#148f77')
mp.plot(loopij5, 's--', label='Trial 5', color='#f4d03f')
mp.plot(loopij6, 's--', label='Trial 6', color='#dc7633')
mp.plot(loopij7, 's--', label='Trial 7', color='#a6acaf')
mp.plot(loopij8, 's--', label='Trial 8', color='#73c6b6')
mp.plot(loopij9, 's--', label='Trial 9', color='#85c1e9')
mp.plot(loopij10, 's--', label='Trial 10', color='#17202a')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()
