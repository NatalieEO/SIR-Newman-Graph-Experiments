# %%
import pandas as pd
import plotly
import matplotlib.pyplot as mp
import plotly.plotly as py 
import plotly.graph_objs as go
import numpy as np
from plotly.graph_objs import *
import plotly.figure_factory as FF

def createChart(csvFile):   
    chart = pd.read_csv(csvFile, sep=',')
    chart['PortionInf'] = chart['NumInfected']/chart['NumNodes']
    chart['InfRate'] = chart['InfRate']/10000
    chart = chart[['InfRate', 'PortionInf']]
    chart = chart.groupby('InfRate').mean()
    return chart;

# %%
Newman_GS10_AD5_C02 = createChart("../1milData/giantComponent/Summer/Newman-1mil-GS10-AD5-C02.csv")
BipNewman_GS10_AD5_C02 = createChart("../1milData/giantComponent/Summer/BipNewman-1mil-GS10-AD5-C02.csv")

# %% [markdown]
# <h1>1 million nodes, Group Size 10, Average Degree 5, CC = 0.2</h1>

# %%
mp.figure(figsize=(25,12))
mp.title('Newman vs BipNewman, Clustering = 0.2', fontsize=22)

mp.plot(Newman_GS10_AD5_C02, 'ms--', label='Newman')
mp.plot(BipNewman_GS10_AD5_C02, 'ms--', label='Bipartite', color='#F781F3')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
Newman_GS30_AD5_C02 = createChart("../1milData/giantComponent/Summer/Newman-1mil-GS30-AD5-C02.csv")
BipNewman_GS30_AD5_C02 = createChart("../1milData/giantComponent/Summer/BipNewman-1mil-GS30-AD5-C02.csv")

# %% [markdown]
# <h1>1 million nodes, Group Size 30, Average Degree 5, CC = 0.2</h1>

# %%
mp.figure(figsize=(25,12))
mp.title('Newman vs BipNewman, Clustering = 0.2', fontsize=22)

mp.plot(Newman_GS30_AD5_C02, 'ms--', label='Newman')
mp.plot(BipNewman_GS30_AD5_C02, 'ms--', label='Bipartite', color='#F781F3')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()

# %%
Newman_GS30_AD15_C02 = createChart("../1milData/giantComponent/Summer/Newman-1mil-GS30-AD15-C02.csv")
BipNewman_GS30_AD15_C02 = createChart("../1milData/giantComponent/Summer/BipNewman-1mil-GS30-AD15-C02.csv")

# %% [markdown]
# <h1>1 million nodes, Group Size 30, Average Degree 15, CC = 0.2</h1>

# %%
mp.figure(figsize=(25,12))
mp.title('Newman vs BipNewman,Group Size 30, Average Deg 15 Clustering = 0.2', fontsize=22)

mp.plot(Newman_GS30_AD15_C02, 'ms--', label='Newman')
mp.plot(BipNewman_GS30_AD15_C02, 'ms--', label='Bipartite', color='#F781F3')

legend = mp.legend(loc='upper left', shadow=True)
for label in legend.get_texts():
    label.set_fontsize('large')

for label in legend.get_lines():
    label.set_linewidth(1.5)
mp.show()
